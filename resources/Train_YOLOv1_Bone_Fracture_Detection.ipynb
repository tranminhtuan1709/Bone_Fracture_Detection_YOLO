# %%
# !pip install torch
# !pip install numpy
# !pip install matplotlib
# !pip install collections
# !pip install torchvision
# !pip install tqdm
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections
# ...

# %%
rm -rf /kaggle/working/*

# %%
# !wget https://raw.githubusercontent.com/tranminhtuan1709/YOLOv1-Implementation/main/source/dataset.py
# !wget https://raw.githubusercontent.com/tranminhtuan1709/YOLOv1-Implementation/main/source/loss.py
# !wget https://raw.githubusercontent.com/tranminhtuan1709/YOLOv1-Implementation/main/source/model.py
# !wget https://raw.githubusercontent.com/tranminhtuan1709/YOLOv1-Implementation/main/source/train.py
# !wget https://raw.githubusercontent.com/tranminhtuan1709/YOLOv1-Implementation/main/source/utils.py

# !ls
# Out:
# --2024-08-24 12:22:10--  https://raw.githubusercontent.com/tranminhtuan1709/YOLOv1-Implementation/main/source/dataset.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4233 (4.1K) [text/plain]
# Saving to: 'dataset.py'
#
# dataset.py          100%[===================>]   4.13K  --.-KB/s    in 0s
#
# 2024-08-24 12:22:10 (57.6 MB/s) - 'dataset.py' saved [4233/4233]
#
# --2024-08-24 12:22:11--  https://raw.githubusercontent.com/tranminhtuan1709/YOLOv1-Implementation/main/source/loss.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# ...

# %%
# %run train.py
# Out:
# Loading dataset!
# Loading dataloader!
# Starts epochs!
# 0
# Train mAP: 0.0
# 100%|██████████| 34/34 [00:30<00:00,  1.11it/s, loss=239]
# Mean loss was 443.0042549582089
# 1
# Train mAP: 0.0
# 100%|██████████| 34/34 [00:29<00:00,  1.15it/s, loss=192]
# Mean loss was 211.66903551887063
# 2
# Train mAP: 0.0007628318853676319
# 100%|██████████| 34/34 [00:29<00:00,  1.14it/s, loss=134]
# Mean loss was 149.26630042580996
# 3
# Train mAP: 0.11855802685022354
# 100%|██████████| 34/34 [00:29<00:00,  1.14it/s, loss=105]
# Mean loss was 111.65229101742015
# 4
# Train mAP: 0.31013667583465576
# 100%|██████████| 34/34 [00:29<00:00,  1.14it/s, loss=95.8]
# Mean loss was 92.57167457131779
# 5
# Train mAP: 0.466187983751297
# 100%|██████████| 34/34 [00:29<00:00,  1.14it/s, loss=78.6]
# Mean loss was 78.58303294462316
# 6
# Train mAP: 0.549113392829895
# 100%|██████████| 34/34 [00:29<00:00,  1.14it/s, loss=56.6]
# Mean loss was 69.60501749375287
# 7
# Train mAP: 0.64818274974823
# ...
